# %%
pip install pandas-gpt
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import openai
openai.api_key = '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'

# %%
import pandas as pd
import pandas_gpt
df = pd.read_csv("D:\Data Analysis\Datasets\BMIAnalysis.csv", nrows=5000)
df
# Out:
#       Age  Gender  Weight_Kilograms  Height_InCentimetres  BMICalculation  \
# 0      18  Female         53.070264                165.10           19.47
# 1      18  Female         58.966960                160.02           23.03
# 2      18  Female         66.224432                162.56           25.06
# 3      18  Female         68.492392                167.60           25.10
# 4      18  Female         69.853168                154.94           29.10
# ...   ...     ...               ...                   ...             ...
# 4995   35  Female        130.180904                167.64           46.32
# 4996   35  Female        130.634496                177.80           41.32
# 4997   35  Female        131.088088                167.64           46.65
# 4998   35  Female        133.809640                167.64           47.61
# 4999   35  Female        135.170416                157.48           54.50
#
#      ObesityLevel  PregnantOrBreastfeedingOrTryingToGetPregnant  \
# ...

# %%
df.ask('plot Age and Gender')

# %%
df.ask('plot obesity level and count')

# %%
df.ask('plot obesity level and gender wise distribution')

# %%
df.ask('scatter plot Weight_Kilograms and Height_InCentimetres')

# %%
df.ask('chart Overweight obesity level due to Lack of exercise')

# %%
df.ask('chart Overweight obesity level due to smoke')

# %%
df.ask('plot age and obesity level due to smoke')

# %%
df.ask('plot age and obesity level exculde None due to smoke')

# %%
df.ask('bar chart age and obesity level exculde None due to smoke')

# %%
df.ask('plot age and weight')

# %%
df.ask('line chart age and weight')

# %%
df.ask('plot age and height')

# %%
df.ask('line bar chart age and weight')

# %%
df.ask('line chart age above 30 and over weight obesity level')
